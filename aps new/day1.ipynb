# %% [markdown]
# <h1> This is my first class <h1>

# %% [markdown]
# # Heading 1

# %% [markdown]
# ## heading 2

# %% [markdown]
# ### heading 3

# %% [markdown]
# #### heading 4

# %% [markdown]
# ##### heading 5

# %% [markdown]
# Welcome to skills4future program from edunet Foundation at Shree LR tiwari college of engineering .

# %%
print("Hello. My name is Apeksha !")
# Out:
# Hello. My name is Apeksha !

# %%
print("Main duniya me akela hu !!")
# Out:
# Main duniya me akela hu !!

# %%
x = 'Shree lr tiwari college of engineering'

# %%
type(x)
# Out:
# str

# %%
y = 10.5
type(y)
# Out:
# float

# %%
z= "10" 
type(z)
# Out:
# str

# %%
a = 64
type(a)
# Out:
# int

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# __ dunder function  are used in oop.

# %%
#this is my first comment 
l1= [1,2,3,4,5, "a"]
type(l1)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 'a']

# %%
print(l1[0])
l1[4:]
# Out:
# 1
# [5, 'a']

# %%
l1[-1]
# Out:
# 'a'

# %%
l1[1:4]
# Out:
# [2, 3, 4]

# %%
l1.append(10)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 'a', 10, 10]

# %%
l1.remove(10) #does not returns which element was removed. 

print(l1)
# Out:
# [1, 2, 3, 4, 5, 'a', 10]

# %%
l1.insert(5,"new") #shift + tab 
print(l1) #print is not req.
# Out:
# [1, 2, 3, 4, 5, 'new', 'a', 10]

# %%
l1.pop(2) #returns which element was removed.
# Out:
# 1

# %%
l1.reverse()
l1
# Out:
# ['a', 'new', 5, 4, 3, 2, 1]

# %%
fruits = ["cherry ", "Apple", "mango", "Banana"]
fruits.sort()
fruits
# Out:
# ['Apple', 'Banana', 'cherry ', 'mango']

# %%
x = 'HelloNew'
x[::-1] #reversing a string
# Out:
# 'weNolleH'

# %%
fruit1 = ['litchi', 'orange', 'watermelon','grapes', 'avacado']
fruits.extend(fruit1)
fruits
# Out:
# ['Apple',
#  'Banana',
#  'cherry ',
#  'mango',
#  'litchi',
#  'orange',
#  'watermelon',
#  'grapes',
#  'avacado']

# %%
fruits.index("mango")
# Out:
# 3

# %%
fruits.clear() # removes all element
print(fruits)
# Out:
# []

# %%
#tuple
tup1 = (1,4,7,8,8,5,5,3,23)
tup1
# Out:
# (1, 4, 7, 8, 8, 5, 5, 3, 23)

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
tup1.count(3)
# Out:
# 1

# %%
tup1.index(23)
# Out:
# 8

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
#set - unique elements only 
set1 ={ 2,3,4,5,6,34,5,55,5,55}
set1
# Out:
# {2, 3, 4, 5, 6, 34, 55}

# %%
set2 ={3,54,6,7,7,8,23,4,55,54,4,9}
set2
# Out:
# {3, 4, 6, 7, 8, 9, 23, 54, 55}

# %%
set1.union(set2) #all values w/o duplicates
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 23, 34, 54, 55}

# %%
set1.intersection(set2) #common values w/o duplicates
# Out:
# {3, 4, 6, 55}

# %%
set1.difference(set2) #elements in set1 but not in set2
# Out:
# {2, 5, 34}

# %%
set1.discard(10)
set1
# Out:
# {2, 3, 4, 5, 6, 34, 55}

# %%
set1.remove(10) #error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10192/760318040.py in <module>
# ----> 1 set1.remove(10)
#
# KeyError: 10

# %%
#dictionary - unique keys 
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
dict1 = { 1: "Apeksha", 2: "sneha"}
dict1.values()
# Out:
# dict_values(['Apeksha', 'sneha'])

# %%
dict1.keys()
# Out:
# dict_keys([1, 2])

# %%
dict1
# Out:
# {1: 'Apeksha', 2: 'sneha'}

# %%
dict1.pop(2)
# Out:
# 'sneha'

# %%
#conditional statements 
#if
x= 10 
if x>0:
    print("x is greater")
# Out:
# x is greater

# %%
#if-else
x= 0 
if x>=10:
    print("x is greater")
else:
    print("x is smaller")
# Out:
# x is smaller

# %%
#elif
x= 98
if x>100:
    print("x is greater 100")
elif x == 100:
    print("x is 100")
else:
    print("x is smaller than 100")
# Out:
# x is smaller than 100

# %%
#loops 
#while 
count = 0;
while count < 10:
    print(count)
    count = count+1

# %%
count = 10
while count >=0:
    print(count)
    count = count-1

# %%
#for loop
for i in range (1,11,2): #start, stop, increment 
    print(i)

# %%
x=10
y=20
hex(id(x))
# Out:
# '0x18308456a50'

# %%
x== y
# Out:
# False

# %%
n= 'Mumbai'
'm' in n
# Out:
# True

# %%
'r' +'m'+'s' #concat
# Out:
# 'rms'

# %%
x,y,z,= 10,11,12
x+y+z
# Out:
# 33

# %%
x>10 and y<20
# Out:
# False

# %%
x>10 or y <20
# Out:
# True

# %%
x!=10
# Out:
# False

# %%
x==10
# Out:
# True

# %%
#function 
def func1(x,y):
    return x+y
    
func1(10,20)
# Out:
# 30

# %%
def add(*args): #multiple args acceptable 
    return sum(args)
add(10,2,3,3,4,5,6,7)
# Out:
# 40

# %%
def sqaure_of_num(a):
    return a*a
sqaure_of_num(7)
# Out:
# 49

# %%
def add_sqaure_of_num(a,b):
    return a*a+b*b
add_sqaure_of_num(2,3)
# Out:
# 13

# %%
#lambda function - anonymous  , performs only 1 operation(uni-operation) 
y= lambda x: x+1 
y(2)
# Out:
# 3

# %%
z= lambda x,y: x*y #mul
z(2,3)
# Out:
# <function __main__.<lambda>(x, y)>

# %%
a = lambda x,y :x+y #add
a(2,3)
# Out:
# 5

# %%
z= lambda x,y: x*x+y*y #square sum
z(2,3)
# Out:
# 13

# %%
#dataset 
stud = {'Name':["Apeksha", "Sneha", "Shivam", "Priya", "Unnati"], 
        'Age':[20,23,23,24,21], 
        'Place': ["Virar", "dahisar", "Kandivali", "Andheri", "Vasai"]}

# %%
import pandas as pd
df= pd.DataFrame(stud)
df
# Out:
#       Name  Age      Place
# 0  Apeksha   20      Virar
# 1    Sneha   23    dahisar
# 2   Shivam   23  Kandivali
# 3    Priya   24    Andheri
# 4   Unnati   21      Vasai

# %%
pte - performance, task ,experience
